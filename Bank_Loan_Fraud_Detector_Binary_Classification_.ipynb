# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("data_for_training.csv")
print(df.head())
# Out:
#      <input type="file" id="files-c6474720-dc76-4b95-9e72-fd432420138b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6474720-dc76-4b95-9e72-fd432420138b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from numpy._core.defchararray import count
from IPython.utils.text import string
import numpy as np
import pandas as pd

df = pd.read_csv("data_for_training.csv")
print("Columns:", df.columns.tolist())   # Confirm it loaded correctly

# Data Understanding
df.columns.to_list()
print(df.isnull().sum())  #Check missing values
df[df["monthly_expense"] < 10000].shape[1] # no of "expense" values less than 10000

X = df.drop(columns="target")  # target column name will be dropped because of O/P column
y = df["target"]
X
df.isnull().sum(axis=1)/ df.shape[1]*100  # % of missing value in each row
df.isnull().sum()/df.shape[0]             # % of missing value in each row

l=[]
for i in df['avg_wallet_balance'].unique().tolist():
    if type(i) not in [string]:
        l.append(i)
print (l)
# Out:
# Columns: ['monthly_income', 'monthly_expense', 'age', 'has_smartphone', 'has_wallet', 'avg_wallet_balance', 'on_time_payment_ratio', 'num_loans_taken', 'target']
# monthly_income           0
# monthly_expense          0
# age                      0
# has_smartphone           0
# has_wallet               0
# avg_wallet_balance       0
# on_time_payment_ratio    0
# num_loans_taken          0
# target                   0
# dtype: int64
# ...

# %%
from sklearn.model_selection import train_test_split
# 80% - Train Data, 20%- Test Data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=True
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
# Scale features BEFORE fitting
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

def ann_model_regressor():
    model = Sequential()
    model.add(Dense(units=6, input_dim=8, activation='relu', kernel_initializer="uniform"))
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer="uniform"))
    model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])
    return model

# %%
model = ann_model_regressor()
model.fit(X_train, y_train, batch_size=10, epochs=80)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8365 - loss: 0.6398
# Epoch 2/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9170 - loss: 0.4157
# Epoch 3/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9437 - loss: 0.2644
# Epoch 4/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9467 - loss: 0.1933
# Epoch 5/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9486 - loss: 0.1595
# Epoch 6/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9492 - loss: 0.1414
# Epoch 7/80
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9529 - loss: 0.1297
# Epoch 8/80
# ...

# %%
import joblib
joblib.dump(sc, "scaler.pkl")
print("Scaler saved!")
# Out:
# Scaler saved!

# %%
ypred_train = model.predict(X_train)
ypred_test = model.predict(X_test)

ypred_train_class = (ypred_train >= 0.5).astype(int)
ypred_test_class  = (ypred_test  >= 0.5).astype(int)

from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from sklearn.metrics import confusion_matrix
# Accuracy
print("Train Accuracy:", accuracy_score(y_train, ypred_train_class))
print("Test Accuracy:", accuracy_score(y_test, ypred_test_class))
# ROC-AUC
print("ROC-AUC Train:", roc_auc_score(y_train, ypred_train))
print("ROC-AUC Test:", roc_auc_score(y_test, ypred_test))
print(confusion_matrix(y_test, ypred_test_class))
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Train Accuracy: 0.9764705882352941
# Test Accuracy: 0.9603960396039604
# ROC-AUC Train: 0.9966898577612864
# ROC-AUC Test: 0.9950300422817298
# [[215   6]
#  [ 10 173]]

# %%
import os
print(os.listdir())
from google.colab import files
files.download("scaler.pkl")
files.download("loan_model.keras")
# Out:
# ['.config', 'data_for_training.csv', 'scaler.pkl', 'sample_data']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8606/1194377293.py in <cell line: 0>()
#       3 from google.colab import files
#       4 files.download("scaler.pkl")
# ----> 5 files.download("loan_model.keras")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: loan_model.keras

# %%
# Save Keras model
model.save('loan_model.keras')
print("Model saved!")
# Out:
# Model saved!

# %%
import numpy as np
from flask import Flask, request, render_template
from keras.models import load_model
import joblib
app = Flask(__name__, template_folder='templates')
# Load model (Keras)
LoanRepay = load_model("loan_model.keras")
# Load scaler (VERY IMPORTANT)
scaler = joblib.load("scaler.pkl")

#Home page
@app.route('/')
def main():
    return render_template('index.html')

@app.route('/predict', methods=['POST'])
def predict():

    final_features = [float(x) for x in request.form.values()]

    # Convert to numpy array
    final_array = np.array(final_features).reshape(1, -1)

    # Apply scaling (same as training)
    final_array = scaler.transform(final_array)

    # Predict probability
    prediction = LoanRepay.predict(final_array)

    # Convert to class (0 or 1)
    output = int(prediction[0][0] >= 0.5)

    return render_template('index.html', prediction=output)

if __name__ == "__main__":
    app.run(debug=True, host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with watchdog (inotify)
